# %% [markdown]
# # Clean up Dataset

# %%
import requests
import pandas as pd

import plotly.express as px

# %%
speadsheet_urls = {
    "targets": (
        "https://docs.google.com/spreadsheets/d/e/"
        "2PACX-1vRe7-Yk7TxigT4MK3qz-RbuVt7lZu0u4vQjiqotiXCT1Ynb9sUrO7tA1RdPemXKaE2dD8IYYO5K0E1C"
        "/pub?gid=1971059158&single=true&output=csv"
    ),
    "sensors": (
        "https://docs.google.com/spreadsheets/d/e/"
        "2PACX-1vRe7-Yk7TxigT4MK3qz-RbuVt7lZu0u4vQjiqotiXCT1Ynb9sUrO7tA1RdPemXKaE2dD8IYYO5K0E1C"
        "/pub?gid=1162044269&single=true&output=csv"
    )
}

# %%
df_targets = pd.read_csv(speadsheet_urls["targets"]).dropna(how="all",axis=0)

# %%
df_sensors = pd.read_csv(speadsheet_urls["sensors"]).dropna(how="all",axis=0)

# %% [markdown]
# ## Clean up Dataset

# %%
df_sensors
# Out:
#        timestamp  number         xi      angle1     angle2      angle3
# 0   1.685202e+09     1.0  30.349058  102.826524  78.934115   55.380485  \
# 1   1.685202e+09     2.0  27.746008   84.872989  78.579592   77.837514
# 2   1.685202e+09     3.0  33.933372   69.634706  78.477926   86.557353
# 3   1.685202e+09     4.0  32.296450   88.327185  72.236072   78.666767
# 4   1.685202e+09     5.0  42.915493   95.966712  76.616117   64.323772
# 5   1.685202e+09     6.0  34.262257   84.959471  72.728988   94.789920
# 6   1.685202e+09     7.0  30.932693  100.782697  70.893048   71.842061
# 7            NaN     NaN        NaN         NaN        NaN         NaN
# 9   1.685266e+09     1.0  33.926760   92.238052  73.229621   80.867670
# 10  1.685266e+09     2.0  37.301163   78.674915  78.505497   79.603731
# 11  1.685266e+09     3.0  33.205440   92.604590  73.819985   80.176053
# 12  1.685266e+09     4.0  33.753890  100.158695  77.393770   80.138260
# 13  1.685266e+09     5.0  30.460072   93.770290  73.032575   77.401035
# 14  1.685266e+09     6.0  35.048440  107.512127  76.571140   78.077303
# 15  1.685266e+09     7.0  32.252250   98.934725  76.697706   73.010585
# 16  1.685267e+09     8.0  28.527899   79.351778  75.281876   80.738090
# 17  1.685267e+09     9.0  32.810043  106.572952  73.259174   77.355404
# 18  1.685267e+09    10.0  32.292200   99.934863  81.719756   56.832239
# 19  1.685267e+09    11.0  37.546120  101.421603  78.856542   75.674690
# 20  1.685267e+09    12.0  29.921467  104.509524  78.841244   59.756473
# 21  1.685267e+09    13.0  39.014300  102.875019  74.041754   74.936205
# 22  1.685267e+09    14.0  33.419228   99.094053  77.038026   80.941026
# 23  1.685267e+09    15.0  34.615364   91.576944  77.378729   80.414397
# 24  1.685267e+09    16.0  38.829807  106.651401  78.694899   76.825854
# 25  1.685267e+09    17.0  29.295574   93.154171  73.279612   84.408297
# 26  1.685267e+09    18.0  34.067800   34.120620  78.112539  118.332074
# 27  1.685267e+09    19.0  32.453760  102.644300  77.848005   77.636658
# 28  1.685267e+09    20.0  30.470290  106.832438  77.404312   56.157513
# 29  1.685268e+09    21.0  35.069706  112.850604  76.875168   72.996513
# 22  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  4.0
# 23  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  4.0
# 24  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  4.0
# 25  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  5.0
# 26  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  5.0
# 27  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  5.0
# 28  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  5.0
# 29  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  6.0
# 30  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  6.0
# 31  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  6.0
# 32  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  6.0
# 33  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  7.0
# 34  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  7.0
# 35  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  7.0
# 36  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  7.0
# 37  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  8.0
# 38  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  8.0
# 39  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  8.0
# 40  LM Recurve 2022  1300 orange    1.0      20m  WA Full (122cm)  8.0
# 42  LM Recurve 2022  1300 orange    1.0      30m  WA Full (122cm)  1.0
# 43  LM Recurve 2022  1300 orange    1.0      30m  WA Full (122cm)  1.0
# 44  LM Recurve 2022  1300 orange    1.0      30m  WA Full (122cm)  1.0
# 45  LM Recurve 2022  1300 orange    1.0      30m  WA Full (122cm)  1.0
# 46  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  1.0
# 47  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  1.0
# 48  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  1.0
# 49  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  1.0
# 50  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  2.0
# 51  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  2.0
# 52  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  2.0
# 53  LM Recurve 2022  1300 orange    2.0      30m  WA Full (122cm)  2.0
#
#    Timestamp  Points  Arrow numbers         x         y
# 0   18:52:37     8.0            1.0 -0.146552  0.200621
# 1   18:52:37    10.0            1.0  0.048276  0.012069
# 2   18:52:37     8.0            1.0 -0.008621 -0.222414
# 3   18:52:37    10.0            1.0  0.096552 -0.001724
# 4   18:55:19    10.0            1.0  0.000000  0.075000
# 5   18:55:19     8.0            1.0 -0.003448 -0.248276
# 6   18:55:19     8.0            1.0 -0.003448 -0.298276
# 7   18:55:19     7.0            1.0  0.194828 -0.294827

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'Title=Training (2023-05-27)<br>Points=%{x}<extra></extra>',
#               'legendgroup': 'Training (2023-05-27)',
#               'marker': {'color': '#636efa'},
#               'name': 'Training (2023-05-27)',
#               'notched': False,
#               'offsetgroup': 'Training (2023-05-27)',
#               'orientation': 'h',
#               'showlegend': True,
#               'type': 'box',
#               'x': array([ 8., 10.,  8., 10., 10.,  8.,  8.,  7.]),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y0': ' ',
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
#               'hovertemplate': 'Title=20m Training (2023-05-28)<br>Points=%{x}<extra></extra>',
#               'legendgroup': '20m Training (2023-05-28)',
#               'marker': {'color': '#EF553B'},
#               'name': '20m Training (2023-05-28)',
#               'notched': False,
#               'offsetgroup': '20m Training (2023-05-28)',
#               'orientation': 'h',
#               'showlegend': True,
#               'type': 'box',
#               'x': array([ 6.,  7.,  8.,  9.,  7.,  8.,  8., 10.,  7.,  8., 10.,  7.,  9.,  9.,
#                            7.,  6.,  8.,  7.,  7.,  4.,  6.,  9.,  7.,  7.,  9.,  8.,  7.,  8.,
#                            9., 10.,  9.,  9.]),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y0': ' ',
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
#               'hovertemplate': 'Title=30m Training (2023-05-28)<br>Points=%{x}<extra></extra>',
#               'legendgroup': '30m Training (2023-05-28)',
#               'marker': {'color': '#00cc96'},
#               'name': '30m Training (2023-05-28)',
#               'notched': False,
#               'offsetgroup': '30m Training (2023-05-28)',
#               'orientation': 'h',
#               'showlegend': True,
#               'type': 'box',
#               'x': array([8., 8., 7., 7., 7., 7., 6., 9., 5., 5., 7., 4.]),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y0': ' ',
#               'yaxis': 'y'}],
#     'layout': {'boxmode': 'group',
#                'legend': {'title': {'text': 'Title'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Points'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0]}}
# })

# %%
px.box(
    df_sensors,
    x="xi",
    color="Title",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="7bc90483-80d8-46c7-8c95-a4e61de29c52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bc90483-80d8-46c7-8c95-a4e61de29c52")) {                    Plotly.newPlot(                        "7bc90483-80d8-46c7-8c95-a4e61de29c52",                        [{"alignmentgroup":"True","hovertemplate":"Title=Training (2023-05-27)<br>xi=%{x}<extra></extra>","legendgroup":"Training (2023-05-27)","marker":{"color":"#636efa"},"name":"Training (2023-05-27)","notched":false,"offsetgroup":"Training (2023-05-27)","orientation":"h","showlegend":true,"x":[30.349058,27.746008,33.933372,32.29645,42.915493,34.262257,30.932693,null],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Title=20m Training (2023-05-28)<br>xi=%{x}<extra></extra>","legendgroup":"20m Training (2023-05-28)","marker":{"color":"#EF553B"},"name":"20m Training (2023-05-28)","notched":false,"offsetgroup":"20m Training (2023-05-28)","orientation":"h","showlegend":true,"x":[33.92676,37.301163,33.20544,33.75389,30.460072,35.04844,32.25225,28.527899,32.810043,32.2922,37.54612,29.921467,39.0143,33.419228,34.615364,38.829807,29.295574,34.0678,32.45376,30.47029,35.069706,34.81991,29.311224,32.67905,29.926517,28.82986,27.2101,24.686749,39.943882,37.138313,34.826096,35.952324],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Title=30m Training (2023-05-28)<br>xi=%{x}<extra></extra>","legendgroup":"30m Training (2023-05-28)","marker":{"color":"#00cc96"},"name":"30m Training (2023-05-28)","notched":false,"offsetgroup":"30m Training (2023-05-28)","orientation":"h","showlegend":true,"x":[34.944332,34.4366,30.899786,36.872093,33.340355,33.3667,37.209534,33.17091,38.107937,34.36242,31.965132,33.204075],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %% [markdown]
# ## Check a Specific Group

# %%
df_target_groups = df_targets.groupby("Title")
df_sensor_groups = df_sensors.groupby("Title")

# %%
df_target_groups.groups.keys()
# Out:
# dict_keys(['20m Training (2023-05-28)', '30m Training (2023-05-28)', 'Training (2023-05-27)'])

# %%
selected_group = "Training (2023-05-27)"

# %%
px.scatter(
    x=df_target_groups.get_group(selected_group).Points,
    y=df_sensor_groups.get_group(selected_group).xi,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array([ 8., 10.,  8., 10., 10.,  8.,  8.,  7.]),
#               'xaxis': 'x',
#               'y': array([30.349058, 27.746008, 33.933372, 32.29645 , 42.915493, 34.262257,
#                           30.932693,       nan]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %% [markdown]
# ## Sensor Data

# %%
px.scatter(
    df_sensors,
    x="xi",
    y="angle1",
    color="Title"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Title=Training (2023-05-27)<br>xi=%{x}<br>angle1=%{y}<extra></extra>',
#               'legendgroup': 'Training (2023-05-27)',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Training (2023-05-27)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([30.349058, 27.746008, 33.933372, 32.29645 , 42.915493, 34.262257,
#                           30.932693,       nan]),
#               'xaxis': 'x',
#               'y': array([102.8265239 ,  84.87298877,  69.63470638,  88.32718516,  95.96671219,
#                            84.95947102, 100.7826975 ,          nan]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=20m Training (2023-05-28)<br>xi=%{x}<br>angle1=%{y}<extra></extra>',
#               'legendgroup': '20m Training (2023-05-28)',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '20m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([33.92676 , 37.301163, 33.20544 , 33.75389 , 30.460072, 35.04844 ,
#                           32.25225 , 28.527899, 32.810043, 32.2922  , 37.54612 , 29.921467,
#                           39.0143  , 33.419228, 34.615364, 38.829807, 29.295574, 34.0678  ,
#                           32.45376 , 30.47029 , 35.069706, 34.81991 , 29.311224, 32.67905 ,
#                           29.926517, 28.82986 , 27.2101  , 24.686749, 39.943882, 37.138313,
#                           34.826096, 35.952324]),
#               'xaxis': 'x',
#               'y': array([  92.23805183,   78.67491469,   92.60459012,  100.1586949 ,
#                             93.77028994,  107.5121269 ,   98.93472524,   79.35177838,
#                            106.5729517 ,   99.93486318,  101.4216027 ,  104.5095244 ,
#                            102.875019  ,   99.09405334,   91.57694447,  106.651401  ,
#                             93.15417123,   34.1206199 ,  102.6443004 ,  106.8324385 ,
#                            112.8506038 ,  108.5579697 ,   90.30565426,   89.79516605,
#                             94.98387758,  101.5163871 ,  110.1343083 ,  105.3257314 ,
#                            107.1373094 ,   36.00606586, -164.1439686 ,   85.93382585]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=30m Training (2023-05-28)<br>xi=%{x}<br>angle1=%{y}<extra></extra>',
#               'legendgroup': '30m Training (2023-05-28)',
#               'marker': {'color': '#00cc96', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '30m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([34.944332, 34.4366  , 30.899786, 36.872093, 33.340355, 33.3667  ,
#                           37.209534, 33.17091 , 38.107937, 34.36242 , 31.965132, 33.204075]),
#               'xaxis': 'x',
#               'y': array([ 85.26324751,  50.1850295 ,  89.76561289, 103.9496701 , 102.7177593 ,
#                            89.48288114,  54.79728819,  66.71287373, 101.4790876 ,  89.10238559,
#                            88.28133134,  89.12008426]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'Title'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'xi'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'angle1'}}}
# })

# %%
px.scatter(
    df_sensors,
    x="xi",
    y="angle2",
    color="Title"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Title=Training (2023-05-27)<br>xi=%{x}<br>angle2=%{y}<extra></extra>',
#               'legendgroup': 'Training (2023-05-27)',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Training (2023-05-27)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([30.349058, 27.746008, 33.933372, 32.29645 , 42.915493, 34.262257,
#                           30.932693,       nan]),
#               'xaxis': 'x',
#               'y': array([78.93411506, 78.5795917 , 78.47792607, 72.23607228, 76.6161169 ,
#                           72.72898787, 70.89304775,         nan]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=20m Training (2023-05-28)<br>xi=%{x}<br>angle2=%{y}<extra></extra>',
#               'legendgroup': '20m Training (2023-05-28)',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '20m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([33.92676 , 37.301163, 33.20544 , 33.75389 , 30.460072, 35.04844 ,
#                           32.25225 , 28.527899, 32.810043, 32.2922  , 37.54612 , 29.921467,
#                           39.0143  , 33.419228, 34.615364, 38.829807, 29.295574, 34.0678  ,
#                           32.45376 , 30.47029 , 35.069706, 34.81991 , 29.311224, 32.67905 ,
#                           29.926517, 28.82986 , 27.2101  , 24.686749, 39.943882, 37.138313,
#                           34.826096, 35.952324]),
#               'xaxis': 'x',
#               'y': array([73.2296212 , 78.5054968 , 73.81998546, 77.3937696 , 73.03257529,
#                           76.57113971, 76.69770609, 75.28187581, 73.25917437, 81.71975565,
#                           78.85654231, 78.84124433, 74.0417545 , 77.03802583, 77.37872946,
#                           78.69489945, 73.27961177, 78.11253942, 77.84800481, 77.40431202,
#                           76.87516831, 76.59476849, 78.05783341, 77.6852676 , 75.12926277,
#                           77.08702518, 77.45369525, 75.98311313, 72.94325117, 79.02015041,
#                           89.26885848, 73.72934926]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=30m Training (2023-05-28)<br>xi=%{x}<br>angle2=%{y}<extra></extra>',
#               'legendgroup': '30m Training (2023-05-28)',
#               'marker': {'color': '#00cc96', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '30m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([34.944332, 34.4366  , 30.899786, 36.872093, 33.340355, 33.3667  ,
#                           37.209534, 33.17091 , 38.107937, 34.36242 , 31.965132, 33.204075]),
#               'xaxis': 'x',
#               'y': array([65.32305573, 70.31518544, 70.16800977, 71.51816762, 71.46067131,
#                           72.6122248 , 76.13426512, 76.63894927, 71.1235544 , 71.56364901,
#                           70.93542371, 73.08281223]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'Title'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'xi'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'angle2'}}}
# })

# %%
px.scatter(
    df_sensors,
    x="xi",
    y="angle3",
    color="Title"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Title=Training (2023-05-27)<br>xi=%{x}<br>angle3=%{y}<extra></extra>',
#               'legendgroup': 'Training (2023-05-27)',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Training (2023-05-27)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([30.349058, 27.746008, 33.933372, 32.29645 , 42.915493, 34.262257,
#                           30.932693,       nan]),
#               'xaxis': 'x',
#               'y': array([55.38048474, 77.83751395, 86.5573529 , 78.66676723, 64.3237715 ,
#                           94.7899199 , 71.84206066,         nan]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=20m Training (2023-05-28)<br>xi=%{x}<br>angle3=%{y}<extra></extra>',
#               'legendgroup': '20m Training (2023-05-28)',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '20m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([33.92676 , 37.301163, 33.20544 , 33.75389 , 30.460072, 35.04844 ,
#                           32.25225 , 28.527899, 32.810043, 32.2922  , 37.54612 , 29.921467,
#                           39.0143  , 33.419228, 34.615364, 38.829807, 29.295574, 34.0678  ,
#                           32.45376 , 30.47029 , 35.069706, 34.81991 , 29.311224, 32.67905 ,
#                           29.926517, 28.82986 , 27.2101  , 24.686749, 39.943882, 37.138313,
#                           34.826096, 35.952324]),
#               'xaxis': 'x',
#               'y': array([ 80.86767   ,  79.60373084,  80.17605265,  80.13826035,  77.4010347 ,
#                            78.07730252,  73.01058517,  80.73808987,  77.35540434,  56.83223947,
#                            75.67468995,  59.75647281,  74.93620464,  80.94102579,  80.41439736,
#                            76.82585383,  84.40829708, 118.3320739 ,  77.63665787,  56.15751291,
#                            72.99651333,  76.91940638,  84.44892551,  81.78285549,  77.05605108,
#                            69.84185927,  52.46918878,  57.51232318,  88.78958502, 123.5322331 ,
#                           347.5090441 ,  89.22815556]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=30m Training (2023-05-28)<br>xi=%{x}<br>angle3=%{y}<extra></extra>',
#               'legendgroup': '30m Training (2023-05-28)',
#               'marker': {'color': '#00cc96', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '30m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([34.944332, 34.4366  , 30.899786, 36.872093, 33.340355, 33.3667  ,
#                           37.209534, 33.17091 , 38.107937, 34.36242 , 31.965132, 33.204075]),
#               'xaxis': 'x',
#               'y': array([ 85.48540044, 112.2431941 ,  55.65416719,  78.72142167,  76.48050925,
#                            70.56266883, 104.8110721 ,  89.80559388,  79.76847912,  81.98884528,
#                            84.31390228,  81.61767176]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'Title'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'xi'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'angle3'}}}
# })

# %%
px.scatter(
    df_sensors,
    x="xi",
    y="calibration",
    color="Title"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/anaconda3/envs/playground310/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Title=Training (2023-05-27)<br>xi=%{x}<br>calibration=%{y}<extra></extra>',
#               'legendgroup': 'Training (2023-05-27)',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Training (2023-05-27)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([30.349058, 27.746008, 33.933372, 32.29645 , 42.915493, 34.262257,
#                           30.932693,       nan]),
#               'xaxis': 'x',
#               'y': array([28994., 28994., 28994., 28994., 28994., 28994., 28994.,    nan]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=20m Training (2023-05-28)<br>xi=%{x}<br>calibration=%{y}<extra></extra>',
#               'legendgroup': '20m Training (2023-05-28)',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '20m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([33.92676 , 37.301163, 33.20544 , 33.75389 , 30.460072, 35.04844 ,
#                           32.25225 , 28.527899, 32.810043, 32.2922  , 37.54612 , 29.921467,
#                           39.0143  , 33.419228, 34.615364, 38.829807, 29.295574, 34.0678  ,
#                           32.45376 , 30.47029 , 35.069706, 34.81991 , 29.311224, 32.67905 ,
#                           29.926517, 28.82986 , 27.2101  , 24.686749, 39.943882, 37.138313,
#                           34.826096, 35.952324]),
#               'xaxis': 'x',
#               'y': array([28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994.,
#                           28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994.,
#                           28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994.,
#                           28994., 28994., 28994., 28994., 28994.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Title=30m Training (2023-05-28)<br>xi=%{x}<br>calibration=%{y}<extra></extra>',
#               'legendgroup': '30m Training (2023-05-28)',
#               'marker': {'color': '#00cc96', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '30m Training (2023-05-28)',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([34.944332, 34.4366  , 30.899786, 36.872093, 33.340355, 33.3667  ,
#                           37.209534, 33.17091 , 38.107937, 34.36242 , 31.965132, 33.204075]),
#               'xaxis': 'x',
#               'y': array([28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994., 28994.,
#                           28994., 28994., 28994.]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'Title'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'xi'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'calibration'}}}
# })

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=304c8127-3bc5-4c1e-932a-c13c3d5a188d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
